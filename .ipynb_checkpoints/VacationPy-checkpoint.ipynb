# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df
# Out:
#      City_ID                         City      Lat       Lng  Max Temp  \
# 0          0                    oriximina  -1.7656  -55.8661     31.80
# 1          1                  olonkinbyen  70.9221   -8.7187      3.20
# 2          2                       paphos  34.7667   32.4167     21.88
# 3          3                   chos malal -37.3781  -70.2709     13.55
# 4          4  edinburgh of the seven seas -37.0676  -12.3116     14.38
# ..       ...                          ...      ...       ...       ...
# 593      593                       tadine -21.5500  167.8833     21.23
# 594      594                         flen  59.0583   16.5878     14.05
# 595      595                     zaozersk  69.4005   32.4476      3.87
# 596      596                 keetmanshoop -26.5833   18.1333     13.43
# 597      597                     portland  45.5234 -122.6762     35.45
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 0          37          26        1.38      BR  1694815742
# 1          76           8        5.29      SJ  1694815743
# 2          60           0        3.09      CY  1694815743
# 3          54          36       13.00      AR  1694815744
# 4          94          63       10.43      SH  1694815745
# ..        ...         ...         ...     ...         ...
# 593        81          81       10.17      NC  1694816160
# 594        71         100        2.27      SE  1694816161
# 595        77          96        4.02      RU  1694816161
# 596        36           0        4.34     NaN  1694816162
# 597        27           0        3.60      US  1694815925
#
# [598 rows x 10 columns]

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_humidity_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    size="Humidity",
    scale = 1,
    color="City",
    alpha = 0.5,
    tiles="OSM",
    frame_width=700,
    frame_height=500
    
)

# Display the map
city_humidity_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_cities_df = city_data_df[(city_data_df["Max Temp"] > 29) & (city_data_df["Wind Speed"] < 4.5) & (city_data_df["Cloudiness"] < 25)]

# Drop any rows with null values
ideal_cities_df = ideal_cities_df.dropna()

# Display sample data
ideal_cities_df
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 101      101              laguna  38.4210 -121.4238     34.62        42
# 109      109              newman  37.3138 -121.0208     33.36        20
# 141      141           taoudenni  22.6783   -3.9836     38.57        16
# 233      233     remire-montjoly   4.9167  -52.2667     29.02        79
# 246      246               la'ie  21.6477 -157.9253     31.98        71
# 261      261               crane  31.3974 -102.3501     33.51        31
# 319      319                bhag  29.0415   67.8239     33.84        43
# 333      333            ad dilam  23.9915   47.1627     30.22        22
# 346      346           road town  18.4167  -64.6167     30.05        74
# 358      358      cabo san lucas  22.8909 -109.9124     36.45        62
# 430      430  atotonilco el alto  20.5500 -102.5167     31.74        23
# 492      492      airway heights  47.6446 -117.5933     29.33        23
# 519      519              snyder  32.7179 -100.9176     29.62        44
# 523      523              kourou   5.1552  -52.6478     29.03        81
# 534      534        lincoln city  44.9582 -124.0179     33.26        78
# 597      597            portland  45.5234 -122.6762     35.45        27
#
#      Cloudiness  Wind Speed Country        Date
# 101           0        2.57      US  1694815786
# 109           3        1.78      US  1694815789
# 141          11        3.28      ML  1694815806
# 233          20        1.03      GF  1694815918
# 246          14        2.24      US  1694815923
# 261          20        2.82      US  1694815929
# 319           3        2.85      PK  1694815954
# 333           6        2.56      SA  1694815960
# 346          20        2.06      VG  1694815894
# 358           0        4.12      MX  1694815970
# 430           9        1.20      MX  1694816002
# 492          20        2.06      US  1694816118
# 519           0        3.09      US  1694816129
# 523          19        4.33      GF  1694816131
# 534          23        3.58      US  1694815843
# 597           0        3.60      US  1694815925

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_cities_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()


# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                    City Country      Lat       Lng  Humidity Hotel Name
# 101              laguna      US  38.4210 -121.4238        42
# 109              newman      US  37.3138 -121.0208        20
# 141           taoudenni      ML  22.6783   -3.9836        16
# 233     remire-montjoly      GF   4.9167  -52.2667        79
# 246               la'ie      US  21.6477 -157.9253        71
# 261               crane      US  31.3974 -102.3501        31
# 319                bhag      PK  29.0415   67.8239        43
# 333            ad dilam      SA  23.9915   47.1627        22
# 346           road town      VG  18.4167  -64.6167        74
# 358      cabo san lucas      MX  22.8909 -109.9124        62
# 430  atotonilco el alto      MX  20.5500 -102.5167        23
# 492      airway heights      US  47.6446 -117.5933        23
# 519              snyder      US  32.7179 -100.9176        44
# 523              kourou      GF   5.1552  -52.6478        81
# 534        lincoln city      US  44.9582 -124.0179        78
# 597            portland      US  45.5234 -122.6762        27

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key,
    "limit": 20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make an API request using the params dictionary & format to JSON
    name_address = requests.get(base_url, params=params).json()
    
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# laguna - nearest hotel: Holiday Inn Express & Suites
# newman - nearest hotel: No hotel found
# taoudenni - nearest hotel: No hotel found
# remire-montjoly - nearest hotel: Complexe Belova
# la'ie - nearest hotel: No hotel found
# crane - nearest hotel: No hotel found
# bhag - nearest hotel: No hotel found
# ad dilam - nearest hotel: No hotel found
# road town - nearest hotel: No hotel found
# cabo san lucas - nearest hotel: Comfort Rooms
# atotonilco el alto - nearest hotel: Hotel Estrella
# airway heights - nearest hotel: Days Inn and Suites Airway Heights
# snyder - nearest hotel: Days Inn
# kourou - nearest hotel: SCI Horizon
# lincoln city - nearest hotel: Inn at Lincoln City
# portland - nearest hotel: the Hoxton
#                    City Country      Lat       Lng  Humidity  \
# 101              laguna      US  38.4210 -121.4238        42
# 109              newman      US  37.3138 -121.0208        20
# 141           taoudenni      ML  22.6783   -3.9836        16
# 233     remire-montjoly      GF   4.9167  -52.2667        79
# 246               la'ie      US  21.6477 -157.9253        71
# 261               crane      US  31.3974 -102.3501        31
# 319                bhag      PK  29.0415   67.8239        43
# 333            ad dilam      SA  23.9915   47.1627        22
# 346           road town      VG  18.4167  -64.6167        74
# 358      cabo san lucas      MX  22.8909 -109.9124        62
# 430  atotonilco el alto      MX  20.5500 -102.5167        23
# 492      airway heights      US  47.6446 -117.5933        23
# 519              snyder      US  32.7179 -100.9176        44
# 523              kourou      GF   5.1552  -52.6478        81
# 534        lincoln city      US  44.9582 -124.0179        78
# 597            portland      US  45.5234 -122.6762        27
#
#                              Hotel Name
# 101        Holiday Inn Express & Suites
# 109                      No hotel found
# 141                      No hotel found
# 233                     Complexe Belova
# 246                      No hotel found
# 261                      No hotel found
# 319                      No hotel found
# 333                      No hotel found
# 346                      No hotel found
# 358                       Comfort Rooms
# 430                      Hotel Estrella
# 492  Days Inn and Suites Airway Heights
# 519                            Days Inn
# 523                         SCI Horizon
# 534                 Inn at Lincoln City
# 597                          the Hoxton

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    size="Humidity",
    scale=1,
    color="City",
    alpha=0.5,
    tiles="OSM",
    frame_width=700,
    frame_height=500,
    hover_cols=["Hotel Name", "Country"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
